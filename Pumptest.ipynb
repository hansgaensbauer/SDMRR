# %%
from pump import *

peri = Pump(output = True)
# Out:
# Pump: Stopping Motor:
#
# Pump: 1
#
# Pump:
# Pump: Setting Speed to 50 : 2
#
# Pump:
# Pump: Starting Motor:

# %%
peri.setspeed(1, 60)
# Out:
# Pump: Stopping Motor:

# %%
peri.setdir('cw')
# Out:
# Pump: Setting Direction to CW:

# %%
peri.start(1)
# Out:
# Pump: 2

# %%
peri.stop(1)
# Out:
# Pump: Starting Motor:

# %%
import pyvisa

# %%
rm = pyvisa.ResourceManager()
rm.list_resources()
# Out:
# /home/sdmrr/miniforge-pypy3/envs/radioconda/lib/python3.10/site-packages/pyvisa_py/tcpip.py:121: UserWarning: TCPIP::hislip resource discovery requires the zeroconf package to be installed... try 'pip install zeroconf'
#   warnings.warn(
# ('ASRL/dev/ttyUSB0::INSTR', 'ASRL/dev/ttyAMA0::INSTR')

# %%
dp832 = rm.open_resource('ASRL/dev/ttyAMA0::INSTR')
dp832.read_termination = '\r\n'
dp832.write_termination = '\r\n'

# %%
print(dp832.query('*IDN?'))
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(dp832.query('*IDN?'))
#
# File ~/miniforge-pypy3/envs/radioconda/lib/python3.10/site-packages/pyvisa/resources/messagebased.py:642, in MessageBasedResource.query(self, message, delay)
#     625 def query(self, message: str, delay: Optional[float] = None) -> str:
#     626     """A combination of write(message) and read()
#     627
#     628     Parameters
#    (...)
#     640
#     641     """
# --> 642     self.write(message)
#     644     delay = self.query_delay if delay is None else delay
#     645     if delay > 0.0:
#
# File ~/miniforge-pypy3/envs/radioconda/lib/python3.10/site-packages/pyvisa/resources/messagebased.py:197, in MessageBasedResource.write(self, message, termination, encoding)
#     191         warnings.warn(
# ...
